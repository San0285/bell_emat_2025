# %% [markdown]
# ## Draft: Final Report

# %% [markdown]
# Jaclyn Bell</br>
# 12/07/2025

# %% [markdown]
# For more than 20 years, World of Warcraft has released expansion after expansion, all of which sparked a lot of conversation within gaming communities and digital platforms. I have been playing the game for almost 12 years, so I have seen the hype unfold with every cinematic drop, to the quiet when players go to other games towards the end of expansions, while waiting for an exciting announcement from Blizzard about something new. Recently the reveal of the newest upcoming expansion, Midnight- the second in the Worldsoul Saga, sparked a lot of attention. Not only because it's a new expansion, but it's bringing with it a huge new feature that player have been asking for for years, player housing.</br>
#
# At first I was going to collect data on the hype around Midnight on it's own. But after doing the first data analysis I realized that I can't understand the significance of Midnights Data without comparing it to other expansions. So to determine whether the hype is unigue around the new expansion and the addition of player housing, I am going to compare it to earlier expansions: Dragonflight (2022), and The War Within (2024).
#
# So what I would like to find out is: Online interest in World of Warcraft expansions follows a cyclical pattern, peaking near official announcements, cinematic reveals, and launch windows.

# %% [markdown]
# To answer this question, I am going to use two public sources that reflect how people engage with gaming news online, Google PyTrends, and YouTube Data API. Google Trends will show us data about how often players search for World of Warcraft information over time. YouTube, will show the engagement with content creators. Together I hope to get some good visuals about how this data might build and decline around the end and start of expansions.

# %% [markdown]
# ## Data showing three expansions:
# 1. Dragonflight - Released November 28th, 2022
# 2. The War Within - Released August 26th, 2024
# 3. Midnight - Expected 2026

# %% [markdown]
# ## PyTrends (Google)

# %%
# !pip install requests pandas
from pytrends.request import TrendReq

import requests
import pandas as pd

print("requests imported OK:", requests.__version__)
# Out:
# Requirement already satisfied: requests in c:\users\jacki\anaconda3\envs\data-fa25\lib\site-packages (2.32.5)
# Requirement already satisfied: pandas in c:\users\jacki\anaconda3\envs\data-fa25\lib\site-packages (2.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jacki\anaconda3\envs\data-fa25\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jacki\anaconda3\envs\data-fa25\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jacki\anaconda3\envs\data-fa25\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jacki\anaconda3\envs\data-fa25\lib\site-packages (from requests) (2025.11.12)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jacki\anaconda3\envs\data-fa25\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jacki\anaconda3\envs\data-fa25\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jacki\anaconda3\envs\data-fa25\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jacki\anaconda3\envs\data-fa25\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jacki\anaconda3\envs\data-fa25\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# requests imported OK: 2.32.5

# %% [markdown]
# ### Dragonflight 2022
# Key terms: Dragonflight
#
# -WoW Dragonflight</br>
# -World of Warcraft Dragonflight</br>
# -WoW 2022 expansion
#
# This data is collected from the first cinimatic reveal on April 19th, 2022 to the expansion release on November 15th, 2022.

# %%
py = TrendReq()

keywords = ["WoW Dragonflight", "World of Warcraft Dragonflight", "WoW Dragonflight 2022"]
py.build_payload(keywords, timeframe="2022-04-19 2022-11-15", geo="")

df = py.interest_over_time()
print(df.head(50))
# Out:
#             WoW Dragonflight  World of Warcraft Dragonflight  \
# date
# 2022-04-19               100                              27
# 2022-04-20                73                              16
# 2022-04-21                31                               7
# 2022-04-22                19                               4
# 2022-04-23                15                               3
# 2022-04-24                12                               2
# 2022-04-25                 9                               2
# 2022-04-26                 7                               2
# 2022-04-27                 6                               1
# 2022-04-28                 6                               2
# 2022-04-29                 6                               1
# 2022-04-30                 6                               1
# 2022-05-01                 7                               1
# 2022-05-02                 6                               1
# 2022-05-03                 4                               1
# 2022-05-04                 4                               1
# 2022-05-05                 4                               0
# 2022-05-06                 4                               1
# 2022-05-07                 5                               1
# 2022-05-08                 4                               1
# 2022-05-09                 3                               1
# 2022-05-10                 3                               1
# 2022-05-11                 3                               1
# 2022-05-12                 3                               1
# %%
py = TrendReq()

keywords = ["WoW Midnight", "World of Warcraft Midnight", "player housing", "WoW Midnight 2026"]
py.build_payload(keywords, timeframe="2025-08-19 2025-11-23", geo="")

df = py.interest_over_time()
print(df.head(75))
# Out:
#             WoW Midnight  World of Warcraft Midnight  player housing  \
# date
# 2025-08-19           100                          24               8
# 2025-08-20            74                          21               7
# 2025-08-21            34                          10               6
# 2025-08-22            26                           6               6
# 2025-08-23            23                           6               5
# ...                  ...                         ...             ...
# 2025-10-28             9                           1               7
# 2025-10-29            12                           1               6
# 2025-10-30            11                           2               6
# 2025-10-31            13                           2               5
# 2025-11-01            13                           2               7
#
#             WoW Midnight 2026  isPartial
# date
# 2025-08-19                  1      False
# 2025-08-20                  0      False
# 2025-08-21                  0      False
# 2025-08-22                  0      False
# 2025-08-23                  0      False
# ...                       ...        ...
# 2025-10-28                  0      False
# 2025-10-29                  0      False
# 2025-10-30                  0      False
# 2025-10-31                  0      False
# 2025-11-01                  0      False
#
# [75 rows x 5 columns]

# %% [markdown]
# This Google data is showing weekly search interest (normalized from 0-100) for the terms I input relating to each expansion. I started my data by looking at the first cinematic reveal of Dragonflight in early 2022 to, the reveal of The War Within late 2023, and August 2025 for the reveal of Midnight. I used different keywords that players might use to search online, the two i figured would be the most popular, were starting beginning the expansion name with either a shorthand "WOW" or typing out the whole name "World of Warcraft" I figured those would be the most popular search terms. This dataset did reveal quite a bit for how simple it is. By the interest score, and date, you could get a pretty good picture of when public attention rose vs. when it dropped.
#
# This Google search data actually surprises me, because the feedback for The War Within isn't what I was expecting. The War Within expansion is the first of three in the World Soul Saga. Which I thought was going to have a lot of hype. I know the cinimatic for The War Within got a lof of attention, but according to this data, when the Cinimatic was reveals on November 3rd, 2023 its not showing me those numbers,so I will be curious to see if the YouTube Data shows different results.

# %% [markdown]
# ## YouTube API

# %%
import pandas as pd

API_KEY = "AIzaSyDJ4QC3EeuOIoJe1o4OQkX-_3ZoWRFW_Lc"


def youtube_search(query, max_results=25):
    import requests  
    
    url = "https://www.googleapis.com/youtube/v3/search"
    params = {
        "part": "snippet",
        "q": query,
        "key": API_KEY,
        "type": "video",
        "maxResults": str(max_results)
    }

    r = requests.get(url, params=params)
    print("Status Code:", r.status_code)
    
    data = r.json()
    items = data.get("items", [])
    if not items:
        print("No items found in response.")
        return pd.DataFrame()

    videos = []
    for item in items:
        id_info = item.get("id", {})
        snippet = item.get("snippet", {})

        video_id = id_info.get("videoId")
        if not video_id:
            continue

        videos.append({
            "video_id": video_id,
            "title": snippet.get("title"),
            "description": snippet.get("description"),
            "channel_title": snippet.get("channelTitle"),
            "publish_time": snippet.get("publishTime"),
        })
    
    return pd.DataFrame(videos)

# %% [markdown]
# ### Dragonflight Expansion 2022

# %%
df_dragonflight = youtube_search("World of Warcraft Dragonflight expansion", max_results=25)
df_dragonflight.head()
# Out:
# Status Code: 200
#       video_id                                              title  \
# 0  3ZtedjN1JXY  Dragonflight Announce Cinematic Trailer | Worl...
# 1  Aipy19Xt45U    The Story of Dragonflight - Full Version [Lore]
# 2  7nrV7Tjfsp4  WoW: Dragonflight From A Casual’s Perspective ...
# 3  nDxhnFTGzSk  WoW&#39;s Best Expansion Yet? Why People Love ...
# 4  WHwSlOLXqXs  World of Warcraft: Dragonflight’s Dracthyr Evo...
#
#                                          description      channel_title  \
# 0  Revel in the power of dragons. - New Race & Cl...  World of Warcraft
# 1  The expansion Dragonflight is just about over ...           Nobbel87
# 2  Spent the last couple weeks of 2022 playing th...              Bloom
# 3  Video by Nixxiom https://www.youtube.com/watch...     Asmongold TV
# 4  World of Warcraft's first ever race and class ...                IGN
#
#            publish_time
# 0  2022-04-19T16:09:08Z
# 1  2024-02-25T23:00:06Z
# 2  2023-01-06T13:30:01Z
# 3  2022-12-11T16:00:30Z
# 4  2022-11-16T11:00:46Z

# %%
def youtube_video_stats(video_ids):
    if not video_ids:
        return pd.DataFrame()
        
    url = "https://www.googleapis.com/youtube/v3/videos"
    params = {
        "part": "statistics",
        "id": ",".join(video_ids),
        "key": API_KEY
    }
    r = requests.get(url, params=params)
    data = r.json()
    
    items = data.get("items", [])
    stats_rows = []
    for item in items:
        s = item.get("statistics", {})
        stats_rows.append({
            "video_id": item.get("id"),
            "view_count": int(s.get("viewCount", 0)),
            "like_count": int(s.get("likeCount", 0)),
            "comment_count": int(s.get("commentCount", 0)),
        })
    return pd.DataFrame(stats_rows)

stats_dragonflight = youtube_video_stats(df_dragonflight["video_id"].tolist())
df_dragonflight_full = df_dragonflight.merge(stats_dragonflight, on="video_id", how="left")

df_dragonflight_full.head(20)
# Out:
#        video_id                                              title  \
# 0   3ZtedjN1JXY  Dragonflight Announce Cinematic Trailer | Worl...
# 1   Aipy19Xt45U    The Story of Dragonflight - Full Version [Lore]
# 2   7nrV7Tjfsp4  WoW: Dragonflight From A Casual’s Perspective ...
# 3   nDxhnFTGzSk  WoW&#39;s Best Expansion Yet? Why People Love ...
# 4   WHwSlOLXqXs  World of Warcraft: Dragonflight’s Dracthyr Evo...
# 5   21aFG_oI45w  Ranking World of Warcraft Expansions from WORS...
# 6   OEqgWDavyA0  World of Warcraft | Dragonflight Official Anno...
# 7   -K1NeqiOqLs  World of Warcraft Dragonflight Movie - All Cin...
# 8   E-NSoBCADaM  Dragonflight&#39;s Story Explained: All You Ne...
# 9   ea5zUh2O1A8             World of Warcraft: Dragonflight Review
# 10  Pj3MGAlcfyo  Dragonflight Launch Cinematic &quot;Take to th...
# 11  NdswWxrs5Qw  The BEST Zone Of EVERY WoW Expansion | World o...
# 12  14g6HjctkLA  World of Warcraft Dragonflight Official Announ...
# 13  lwF9GfD-VD4  Asmongold shows how BROKEN warriors are by pul...
# 14  3PZau7Xq2CA  Ranking World of Warcraft Expansions. Which on...
# 15  el3RTw6FdVw  What Your Favorite World of Warcraft Expansion...
df_theWarWithin = youtube_search("World of Warcraft The War Within expansion", max_results=25)
df_theWarWithin.head()
# Out:
# Status Code: 200
#       video_id                                              title  \
# 0  o03STclgxSc  The War Within Announce Cinematic | World of W...
# 1  SiIjThwKLaE  Midnight | Intercession Cinematic | World of W...
# 2  zxqQ5DVzJ7Y           World of Warcraft: The War Within Review
# 3  k4fp2wyWqHE  Every WoW Midnight Feature We Know (There&#39;...
# 4  DSvLkzRt9fc  The War Within Features Overview | World of Wa...
#
#                                          description      channel_title  \
# 0  Our heroes Anduin and Thrall find themselves d...  World of Warcraft
# 1  As Midnight draws near, Xal'atath's ravenous v...  World of Warcraft
# 2  World of Warcraft: The War Within reviewed by ...                IGN
# 3  The Midnight reveal was a scattered mess, but ...  Bellular Warcraft
# 4  From deep beneath the surface comes visions of...  World of Warcraft
#
#            publish_time
# 0  2023-11-03T19:44:41Z
# 1  2025-08-19T19:47:38Z
# 2  2024-09-13T23:37:22Z
# 3  2025-08-22T19:12:37Z
# 4  2023-11-03T19:48:01Z

# %%
def youtube_video_stats(video_ids):
    if not video_ids:
        return pd.DataFrame()
        
    url = "https://www.googleapis.com/youtube/v3/videos"
    params = {
        "part": "statistics",
        "id": ",".join(video_ids),
        "key": API_KEY
    }
    r = requests.get(url, params=params)
    data = r.json()
    
    items = data.get("items", [])
    stats_rows = []
    for item in items:
        s = item.get("statistics", {})
        stats_rows.append({
            "video_id": item.get("id"),
            "view_count": int(s.get("viewCount", 0)),
            "like_count": int(s.get("likeCount", 0)),
            "comment_count": int(s.get("commentCount", 0)),
        })
    return pd.DataFrame(stats_rows)

stats_theWarWithin = youtube_video_stats(df_theWarWithin["video_id"].tolist())
df_theWarWithin_full = df_theWarWithin.merge(stats_theWarWithin, on="video_id", how="left")

df_theWarWithin_full.head(20)
# Out:
#        video_id                                              title  \
# 0   o03STclgxSc  The War Within Announce Cinematic | World of W...
# 1   SiIjThwKLaE  Midnight | Intercession Cinematic | World of W...
# 2   zxqQ5DVzJ7Y           World of Warcraft: The War Within Review
# 3   k4fp2wyWqHE  Every WoW Midnight Feature We Know (There&#39;...
# 4   DSvLkzRt9fc  The War Within Features Overview | World of Wa...
# 5   aDKAIp_wVfE  New / Returning Players Guide to WoW The War W...
# 6   y7tGkDQkyek  Cinemática de anuncio de The War Within | Worl...
# 7   f2fj8x7xUHQ   All the lore you NEED to know for The War Within
# 8   22Nf00VN0WM       Midnight Gameplay Reveal | World of Warcraft
# 9   2gzICQiAVmY  The History of World of Warcraft Explained in ...
# 10  21aFG_oI45w  Ranking World of Warcraft Expansions from WORS...
# 11  r53EYv8zs6g  Is WOW worth Playing in 2025? (World of Warcra...
# 12  zYdFLUBjwCU  The War Within Official Cinematic | Shadows Be...
# 13  8nb1eaf8b_g                        New WoW expansion dropped..
# 14  KVegvHJiHs8  The War Within Pre-Expansion Update Trailer | ...
# 15  Z5cr68V4xlw        From Zero to Buying The War Within for FREE
# ### Midnight Expansion 2026

# %%
df_midnight = youtube_search("World of Warcraft Midnight expansion", max_results=25)
df_midnight.head()
# Out:
# Status Code: 200
#       video_id                                              title  \
# 0  ijN4EW6meRk  World of Warcraft: Midnight - Official Opening...
# 1  k4fp2wyWqHE  Every WoW Midnight Feature We Know (There&#39;...
# 2  FRAx1TBJMfg   10 Major Features of World of Warcraft: Midnight
# 3  22Nf00VN0WM       Midnight Gameplay Reveal | World of Warcraft
# 4  WmG98apVwKw             Midnight Deep Dive | World of Warcraft
#
#                                          description      channel_title  \
# 0  Don't miss the Opening Cinematic for World of ...                IGN
# 1  The Midnight reveal was a scattered mess, but ...  Bellular Warcraft
# 2  Twitter (https://twitter.com/MrGMYT) Twitch (h...               MrGM
# 3  As darkness threatens to envelop all of Azerot...  World of Warcraft
# 4  Join Game Director Ion Hazzikostas with a spec...  World of Warcraft
#
#            publish_time
# 0  2025-08-19T19:53:13Z
# 1  2025-08-22T19:12:37Z
# 2  2025-08-19T22:24:39Z
# 3  2025-08-19T19:49:20Z
# 4  2025-10-01T15:55:07Z

# %%
def youtube_video_stats(video_ids):
    if not video_ids:
        return pd.DataFrame()
        
    url = "https://www.googleapis.com/youtube/v3/videos"
    params = {
        "part": "statistics",
        "id": ",".join(video_ids),
        "key": API_KEY
    }
    r = requests.get(url, params=params)
    data = r.json()
    
    items = data.get("items", [])
    stats_rows = []
    for item in items:
        s = item.get("statistics", {})
        stats_rows.append({
            "video_id": item.get("id"),
            "view_count": int(s.get("viewCount", 0)),
            "like_count": int(s.get("likeCount", 0)),
            "comment_count": int(s.get("commentCount", 0)),
        })
    return pd.DataFrame(stats_rows)

stats_midnight = youtube_video_stats(df_midnight["video_id"].tolist())
df_midnight_full = df_midnight.merge(stats_midnight, on="video_id", how="left")

df_midnight_full.head(20)
# Out:
#        video_id                                              title  \
# 0   ijN4EW6meRk  World of Warcraft: Midnight - Official Opening...
# 1   k4fp2wyWqHE  Every WoW Midnight Feature We Know (There&#39;...
# 2   FRAx1TBJMfg   10 Major Features of World of Warcraft: Midnight
# 3   22Nf00VN0WM       Midnight Gameplay Reveal | World of Warcraft
# 4   WmG98apVwKw             Midnight Deep Dive | World of Warcraft
# 5   YU_9X5JDa8w  Housing Early Access Trailer | World of Warcra...
# 6   SiIjThwKLaE  Midnight | Intercession Cinematic | World of W...
# 7   _sIQ1_nB2RY    From Zero to Buying Midnight Expansion for FREE
# 8   dNMlluxPITY  World of Warcraft: Midnight - Official Housing...
# 9   OP6xrJfkk04  World of Warcraft: Midnight – What We Think Af...
# 10  e4313yYIqrg  Midnight | Epic Edition Pre-purchase Trailer |...
# 11  cGqYcOsUZZQ         My Thoughts on World of Warcraft: Midnight
# 12  Je4zPn8oPVM  Midnight | Cinemática de Intercesión | World o...
# 13  RiFKqUejX5Y  New Playable Race in World of Warcraft: Midnig...
# 14  J3HtOZhQJUc          Midnight Beta Trailer | World of Warcraft
# YouTube data was different, but it seemed to complement my Google Data. I gathered the first 20 videos for each expansion, then retireved their engagement statistics based on, title, description, channel, publish dates, and the counts on views, likes, and comments. This gave me an idea of what players seek out as well as what they like to consume. The videos that seemed to get the most engagement as far as views, likes and comments, from World of Warcrafts YouTube channel, and were either cinematics of trailers for some new feature or gameplay.

# %% [markdown]
# Once the datasets from Google and YouTube were collected, I was able to inspect them to identify patterns.</br>
#
# Google Trends did show peaks in engagement around major announcement events, for example Dragonflights spike in April when its cinematic trailer dropped. Midnight did show some moderate interest around the early reveal of player housing, but it wasn't as high as I thought it would be. The data that surprised me the most was the moderate spike The War Within had compared to dragonflight. I feel that The War Within is a more popular expansion amoungst player, but Googles data didn't show as much hype around it.</br>
#
# YouTube engagement showed emphasis on The War Within more strongly than the Google Trends showed. When analyzing the dataset, it consistently got more community interaction as far as video engagement is showing in view, likes and comments.

# %% [markdown]
# ### Collecting and Visualizing Data
#
# For this part of my Analysis, I wanted to grab data to be able to look at, observe, then sort out later either adding to it or omiting some of it. I am going to start with a YouTube search. I want to get information about videos that exist for the three expansions, when they were posted, and who posted them. Then I will look at YouTube stats to measure the engagement of the videos through likes, views, and comments on them.
#
# #### What I expect my findings will show
#
# From a players standpoint, I expect there to be a lot more hype around The War Within expansion, because it is the start of the Trilogy Worldsoul Saga. And the cinimatic reveals were very impressive and showed a lot of exciting things hinting at whats to come for the future of World of Warcraft. But with a the new major feature of player housing, and class changes in the upcoming expansion, Midnight, will it be the most anticipated expansion yet?

# %%
import matplotlib.pyplot as plt

# %%
def youtube_search(query, max_results=25):
    url = "https://www.googleapis.com/youtube/v3/search"
    params = {
        "part": "snippet",          
        "q": query,                 
        "key": API_KEY,             
        "type": "video",            
        "maxResults": str(max_results)  
    }

    r = requests.get(url, params=params)
    r.raise_for_status()
    data = r.json()

    items = data.get("items", [])
    videos = []

    for item in items:
        id_info = item.get("id", {})
        snippet = item.get("snippet", {})
        
        video_id = id_info.get("videoId")
        if not video_id: 
            continue 

        videos.append({
            "video_id": video_id,
            "title": snippet.get("title"),
            "description": snippet.get("description"),
            "channel_title": snippet.get("channelTitle"),
            "publish_time": snippet.get("publishTime"),
        })

    return pd.DataFrame(videos)

# %%
def youtube_video_stats(video_ids):
    if not video_ids:
        return pd.DataFrame()

    url = "https://www.googleapis.com/youtube/v3/videos"
    params = {
        "part": "statistics",
        "id": ",".join(video_ids),  
        "key": API_KEY
    }

    r = requests.get(url, params=params)
    r.raise_for_status()
    data = r.json()

    stats_rows = []
    for item in data.get("items", []):
        s = item.get("statistics", {})
        stats_rows.append({
            "video_id": item.get("id"),
            "view_count": int(s.get("viewCount", 0)),
            "like_count": int(s.get("likeCount", 0)),
            "comment_count": int(s.get("commentCount", 0)),
        })

    return pd.DataFrame(stats_rows)

# %%
# Dragonflight
df_dragon = youtube_search("World of Warcraft Dragonflight expansion", max_results=25)
stats_dragon = youtube_video_stats(df_dragon["video_id"].tolist())
df_dragon_full = df_dragon.merge(stats_dragon, on="video_id", how="left")
df_dragon_full["expansion"] = "Dragonflight"   

# The War Within
df_war = youtube_search("World of Warcraft The War Within expansion", max_results=25)
stats_war = youtube_video_stats(df_war["video_id"].tolist())
df_war_full = df_war.merge(stats_war, on="video_id", how="left")
df_war_full["expansion"] = "The War Within"

# Midnight
df_midnight = youtube_search("World of Warcraft Midnight expansion", max_results=25)
stats_midnight = youtube_video_stats(df_midnight["video_id"].tolist())
df_midnight_full = df_midnight.merge(stats_midnight, on="video_id", how="left")
df_midnight_full["expansion"] = "Midnight"

# Single DataFrame
df_yt_all = pd.concat([df_dragon_full, df_war_full, df_midnight_full], ignore_index=True)

df_yt_all.head()
# Out:
#       video_id                                              title  \
# 0  Aipy19Xt45U    The Story of Dragonflight - Full Version [Lore]
# 1  3ZtedjN1JXY  Dragonflight Announce Cinematic Trailer | Worl...
# 2  -K1NeqiOqLs  World of Warcraft Dragonflight Movie - All Cin...
# 3  E-NSoBCADaM  Dragonflight&#39;s Story Explained: All You Ne...
# 4  kc-P4_GOWL4                  WoW Dragonflight in a Nutshell...
#
#                                          description      channel_title  \
# 0  The expansion Dragonflight is just about over ...           Nobbel87
# 1  Revel in the power of dragons. - New Race & Cl...  World of Warcraft
# 2  Dragonflight All Cutscenes & Cinematics in ORD...         Athelarius
# 3  Head to http://squarespace.com/bellulargaming ...  Bellular Warcraft
# 4  Are you confused about the Dragonflight story ...            Nixxiom
#
#            publish_time  view_count  like_count  comment_count     expansion
# 0  2024-02-25T23:00:06Z      126218        2879            218  Dragonflight
# 1  2022-04-19T16:09:08Z     3545776       60005           5523  Dragonflight
# 2  2024-01-28T16:11:00Z      405200        3640            225  Dragonflight
# 3  2024-07-18T21:01:14Z      204405        4987            344  Dragonflight
# 4  2023-03-29T16:00:25Z       63818        2354            192  Dragonflight

# %% [markdown]
# Next I wanted a compact summary of what that above data was showing me. I wanted to see which expansion was getting the most hype. This information is based on 25 videos of each expansion. Looking at these numbers, it seems that Dragonflight and The War Within are pretty equal as far as the hype around them...with The War Within being slightly ahead. No keep in mind. Midnight has a while until it's launched so that could be a reason for it perfoming so low. There is still information to be released over the next couple months. People might get more excited or curious as it gets closer.

# %%
yt_summary = df_yt_all.groupby("expansion").agg(
    n_videos=("video_id", "count"),           
    total_views=("view_count", "sum"),        
    median_views=("view_count", "median"),    
    mean_views=("view_count", "mean"),        
    total_comments=("comment_count", "sum")   
).round(1)

yt_summary
# Out:
#                 n_videos  total_views  median_views  mean_views  \
# expansion
# Dragonflight          25     19316702      116153.0    772668.1
# Midnight              25     11758181      138650.0    470327.2
# The War Within        25     21852574      380918.0    874103.0
#
#                 total_comments
# expansion
# Dragonflight             16648
# Midnight                 29777
# The War Within           44471

# %% [markdown]
# Lastly I wanted a little visualization of the data. Just to see what I'm working with and what I might want to change later on.
#
# Below the first graph is showing the about equal total views between The War Within and Dragonflight expansion in views, both around 21-22 million. With mightnight way behind, but it should still grow up to the release. And as far as the second graph is showing, The War Within has almost 20 million more average views per video than the other two expansions.

# %%
# Total views per expansion
yt_summary["total_views"].plot(kind="bar", title="Total YouTube views per expansion", ylabel="Total views")
plt.show()

# Median views per video
yt_summary["median_views"].plot(kind="bar", title="Median views per video by expansion", ylabel="Views")
plt.show()

# %% [markdown]
# This next part is going to show a visualization of Google PyTrends data. Which is showing search trends for each expansion, and what I'm seeing is Dragonflight search interest peaked very high in November of 2022 which makes sense, because it was release then. Same goes for The War Within, peaking in August of 2024, for its release. Search trends seem really low for Midnight, especially this late in the year, so I will have to look at my data and see what's going on. But for now this is showing me some good information that I can work with.

# %%
from pytrends.request import TrendReq

py = TrendReq()

keywords = ["Dragonflight", "War Within", "WoW Midnight", "WoW player housing"]

py.build_payload(
    kw_list=keywords,
    timeframe="2022-01-01 2025-11-15",
    geo=""
)

df_trends = py.interest_over_time()

print("Trends DataFrame created? ->", 'df_trends' in globals())
print(df_trends.head())
# Out:
# Trends DataFrame created? -> True
#             Dragonflight  War Within  WoW Midnight  WoW player housing  \
# date
# 2021-12-26             0           0             0                   0
# 2022-01-02             0           1             0                   0
# 2022-01-09             0           1             0                   0
# 2022-01-16             0           0             0                   0
# 2022-01-23             0           1             0                   0
#
#             isPartial
# date
# 2021-12-26      False
# 2022-01-02      False
# 2022-01-09      False
# 2022-01-16      False
# 2022-01-23      False

# %%
ax = df_trends[keywords].plot(
    figsize=(12,6),
    title="Google search interest over time: Dragonflight vs War Within vs Midnight"
)
ax.set_ylabel("Search interest (0–100)")  # normalized to each term's own peak
plt.show()

# %%
trends_summary = pd.DataFrame({
    "max_interest": df_trends[keywords].max(),        # highest spike for each keyword
    "mean_interest": df_trends[keywords].mean().round(2)  # average search interest
})

print(trends_summary)
# Out:
#                     max_interest  mean_interest
# Dragonflight                 100           8.78
# War Within                    78           4.84
# WoW Midnight                   8           0.19
# WoW player housing             0           0.00

# %%
trends_summary["max_interest"].plot(
    kind="bar",
    title="Peak Google search interest per expansion keyword",
    ylabel="Peak interest (0–100)"
)
plt.show()

# %% [markdown]
# And above and below are two other representaions of the same information in the chart above. So far in Google Search trends, Dragonflight seemed to be getting the most engagement.

# %% [markdown]
# Looking at all of this data, it indicates that search behavior was more dramatic for Dragonflight, but content consumption and creator engagement was a lot stronger during The War Within cycle. </br>
#
# Midnight is still in it's early stages. So I can't really tell much about from the data, but there are promising signals from the YouTube data centered about player housing....those videos seem to have decent views compared to some of the other Midnight topics. So I wonder if the future of Midnights online presence will revolve heavily around new systems rather than the expansion's story alone.

# %% [markdown]
# Together my findings support the idea that online interest in World Of Warcraft expansions does follow a cyclical pattern around announcements, cinematic reveals and launch windows, just as my hypothesis predicted. Each expansion had its own unigue rhythm of attention, with Dragonflight producing the largest immediate surge in Google search interest, while The War Within emerged the strongest performer on YouTube. Midnight is getting some decent traction, showing that excitement is still building upon its launch next spring. So I guess expansion hype is indeed measurable but also highly influenced by community behavior across different platforms. Overall, these patterns show how digital interest grows, peaks, and evolves as players respond to each new feature and expansion announced.
